# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/04_Lista_es_dictionary/04_Lista_es_dictionary_elmelet.ipynb)

# %% [markdown]
# # Lista

# %% [markdown]
# - Elemek tárolására alkalmas változó típus.
#
# - Több, összetartozó érték egy helyen történő mentésére használjuk.

# %% [markdown]
# ## Létrehozás és tulajdonságok

# %% [markdown]
# - Létrehozáskor az elemeket szögletes zárójelek `[]` közé tesszük
#
# - Az elemeket vesszővel választjuk el egymástól
#
# - Az elemek sorrendben helyezkednek el
#
# - Tetszőleges típusú elemeket képes tárolni (lista eleme is lehet egy listának)
#
# - A lista számozása 0-val kezdődik!
#
# - Az utolsó elemre -1. elemként tudunk hivatkozni (utolsó előtte -2 ...)
#
# - A lista elemeit meg tudjuk változtatni
#
# ```python
# <lista neve> = [<első elem>, <második elem>, ..., <utolsó elem>]
# ```

# %%
lista_1 = [9, 'alma', 42.42, 'December']
lista_2 = [0, ['banán', 3], 7.95]

# %% [markdown]
# Üres listát kétféleképpen tudunk létrehozni:
#
# Vagy a szögletes zárójelek között nem definiálunk értéket, vagy a lista függvényt hívjuk meg paraméter nélkül.
#
# ```python
# <üres lista> = []
# <üres lista> = list()
#
# ```

# %% [markdown]
# ## Műveletek

# %% [markdown]
# **Összeadás**

# %%
lista = lista_1 + lista_2

# %% [markdown]
# [9, 'alma', 42.42, 'December'] + [ 0, ['banán', 3], 7.95] =

# %%
lista

# %% [markdown]
# **Szorzás egész számmal**

# %%
nulla_lista = [0]
hat_elemu_nulla_lista = [0] * 6

# %%
hat_elemu_nulla_lista

# %% [markdown]
# **Hossz meghatározás**

# %% [markdown]
# Lista hosszának meghatározásához már a stringek esetén megismert `len()` függvényt használjuk:
#
#
# ```python
# len(<lista neve>)
# ```

# %% [markdown]
# <sup>A visszatérési értéke egy (nem negatív) egész szám.</sup>

# %%
len(lista)

# %% [markdown]
# <sup>Vegyük észre, hogy itt az 6. elem (5-ös indexű) az egy két elemből álló lista, viszont csak egy elem.</sup>

# %% [markdown]
# **Lista 'szeletelése'**

# %% [markdown]
# Hasonlóan a stringeknél tanultakhoz, a listában egy elemet szögletes zárójelek `[]` között megadott sorszámának beírásával érünk el, ahol az indexelés 0-val kezdődik.

# %%
lista

# %% [markdown]
# A lista elemeinek a sorszáma:
# ```python
# [9, 'alma', 42.42, 'December', 0, ['banán', 3], 7.95]
#  0    1       2        3       4        5         6
# ```

# %% [markdown]
# Első elem

# %%
lista[0]

# %% [markdown]
# Negyedik elem

# %%
lista[3]

# %% [markdown]
# Ötödik elem első eleme

# %%
lista[5][0]

# %% [markdown]
# Utolsó elemre való hivatkozás

# %%
lista[-1]

# %% [markdown]
# Ha nem létező indexet adunk meg, akkor hibát dob a program:
#
# ```python
# lista[100]
# ```

# %% [markdown]
# Első 4 elem kijelölése

# %%
lista[0:4]

# %% [markdown]
# <sup>Itt fontos észrevenni, hogy az 4-es indexű karakter már nem része a kijelölésnek, vagyis alulról inkluzív, míg felülről exkluzív a darabolás.</sup>

# %% [markdown]
# Harmadik elemtől a lista végéig

# %%
lista[2:]

# %% [markdown]
# Ötödik elemig kettesével
# (🐟)

# %%
lista[:5:2]

# %% [markdown]
# Utolsó három elem visszafelé

# %%
lista[-1:-4:-1]

# %% [markdown]
# **Új elem hozzáfűzése a listához**

# %% [markdown]
# Új elemet az `append()` függvénnyel tudunk a listához hozzáfűzni. Ha viszont egyszerre több elemmel akarjuk bővíteni a listát, akkor a `+` operátort vagy az `extend()` metódust használhatjuk.
#
# - `<lista>.append(<új elem>)` → a lista végéhez hozzá fűződik az `<új elem>`, nem kell új változóba elmenteni ("in-place")
#
# - `+` → az új elemeknek egy `list` típusú változóban kell lenniük, illetve az így kapott listát el kell menteni egy új változóba
#
# - `<lista>.extend(<másik lista>)` → <másik lista> tartalmával kiegészíti az eredeti listát, nem kell új változóba elmenteni ("in-place")

# %% [markdown]
# Append

# %%
print(lista)

# %%
lista.append('új elem')

print(lista)

# %% [markdown]
# <sub>A listának része 'új elem'.</sub>

# %% [markdown]
# Összeadás

# %% [markdown]
# ```python
# lista + 'új-új elem'
# ```

# %% [markdown]
# <sup>Nem megfelelő típusok.</sup>

# %%
lista + ['új-új elem']

# %%
lista

# %% [markdown]
# <sub>A listának nem része 'új-új elem', mert nem mentettük el új változóba.</sub>

# %%
uj_lista = lista + ['új-új elem']

# %%
uj_lista

# %% [markdown]
# Extend

# %%
print(lista)

# %%
lista.extend([1, 'sör'])

print(lista)

# %% [markdown]
# **Korábban hozzáadott elem módosítása**

# %% [markdown]
# Elem módosításához jelöljünk ki egy elemet a fent bemutatott szeleteléses módszerrel és rendeljünk hozzá másik értéket

# %%
lista[0] = 12.03

# %%
lista

# %% [markdown]
# ## Fontosabb függvények

# %% [markdown]
# Fontos vigyázni, mert vannak 'in-place' függvények, amiket lefuttatva megváltozik az eredeti változónk értéke, de vannak olyanok is amiket egy új változóba el kell menteni (vagy az eredetit felülírni), hogy hatásuk legyen.

# %% [markdown]
# Néhány a népszerűbb listákon futtatható függvények közül:
#
#
# - `<lista>.insert(<index>, <elem>)` → beszúr egy elemet a megadott index helyére (in-place)
#
# - `<lista>.remove(<elem>)` → eltávolítja az elemet a listából (in-place)
#
# - `<lista>.reverse()` → megfordítja az elemek sorrendjét (in-place)
#
# - `<lista>.count(<keresett elem>)` → megadja, hogy keresett elem hányszor van jelen a listában
#
# - `<lista>.index(<keresett elem>)` → megadja, hogy keresett elem a lista hányadik eleme
#
# - `<szöveg>.split(<elválasztó szöveg>)` → a külön választott szavakat egy lista egymást követő elemeibe pakolja. Ha nincs megadva elválasztó szöveg akkor white-spacenként (space, tab, enter) vált elemet
#
# - `<szöveg>.join(list(<egyik szöveg>, <másik szöveg>, <harmadik szöveg>))` → a listában jelenlévő szövegeket egymás mellé fűzni a szöveg stringgel elválasztva
#
# - `<elem> in <lista>` → megadja, hogy az adott elem megtalálható e valahol a listában (🐟)

# %%
lista.insert(2, 'új kettes indexű elem')

print(lista)

# %%
lista.remove('új elem')

print(lista)

# %%
lista.reverse()

print(lista)

# %%
lista.count('banán')

# %%
lista.index(1)

# %% [markdown]
# <sup>Ha az elem nincs benne a listában, akkor hibát dob.</sup>

# %%
'új kettes indexű elem'.split()

# %%
'!!!'.join(['csatlakozz', 'hozzánk', 'most'])

# %% [markdown]
# <sup>Csak olyan listán lehet lefuttatni, aminek minden eleme `str` típusú.</sup>

# %% [markdown]
# Néha nem egyértelmű mindig elsőre, hogy mi mit is csinál (😊)
# <details>
# <img src="https://github.com/PythonVilag/Python_alapjai/blob/main/04_Lista_es_dictionary/data/join.jpg?raw=true" alt="drawing", width="500"/>
# </details>

# %%
'alma' in lista

# %% [markdown]
# **Csak azonos típusú elemekből álló listákon elvégezhető függvények**

# %% [markdown]
# - `min(<lista>)`/`max(<lista>)` → megadja a listában szereplő elemek közül a minimálisat/maximálisat
#
# - `sum(<lista>)` → megadja a lista elemeinek az összegét számok esetén
#
# - `sorted(<lista>)` → sorba rendez, de a kimenetet el kell menteni változóba (NEM in-place)

# %%
numerikus_lista = [2.1, 5, 1, 6.5, 3]

# %%
min(numerikus_lista)

# %%
max(numerikus_lista)

# %%
sum(numerikus_lista)

# %%
rendezett_numerikus_lista = sorted(numerikus_lista)

print(rendezett_numerikus_lista)

# %% [markdown]
# A `<lista>.sort()` metódussal in-place is el lehet végezni a sorbarendezést. (🐟)

# %%
numerikus_lista.sort()

print(numerikus_lista)

# %% [markdown]
# Filozófiai kérdések megoldása a `sort()` metódussal (😊)
# <details>
# <img src="https://github.com/PythonVilag/Python_alapjai/blob/main/04_Lista_es_dictionary/data/sort.jpg?raw=true" alt="drawing"/>
# </details>

# %% [markdown]
# # Dictionary

# %% [markdown]
# - A dictionary lényegében ugyanaz, mint a lista, azzal a különbséggel, hogy itt ez elemekre a sorszámuk helyett kulcs értékekkel hivatkozunk.
#
# - Ez azt is jelenti, hogy deklaráláskor meg kell adni a kulcsokat és a hozzájuk tartozó értékeket is.

# %% [markdown]
# ## Létrehozás és tulajdonságok

# %% [markdown]
# - Létrehozáskor az elempárokat kapcsos zárójelek `{}` közé tesszük
#
# - Egy elempár egy kulcsból és egy ahhoz tartozó értékből áll
#
# - Az elempár elemeit kettősponttal választjuk el egymástól: `<kulcs>: <érték>`
#
# - Az elempárokat vesszővel választjuk el egymástól
#
# - Az értékekre sorszámuk helyett a kulcs segítségével hivatkozunk
#
# - A dictionary elemeit meg tudjuk változtatni
#
# ```python
# <dictionary neve> = {<első kulcs>: <első érték>, ..., <utolsó kulcs>: <utolsó érték>}
# ```

# %%
barat = {'név': 'Márton', 'kor': 34, 'hobby': [], 'vicces': True, 'kedvenc sör': ['Borsodi', 'Soproni']}

# %% [markdown]
# Létrehozhatnánk egy listát is, ugyanezekkel az értékekkel, csak ott index segítségével tudnánk rájuk hivatkozni kulcs helyett:
# ```python
# barat = ['Márton', 34, [], True, ['Borsodi', 'Soproni']]
# ```

# %% [markdown]
# ## Műveletek

# %% [markdown]
# **Hivatkozás elemre kulcs használatával**

# %%
barat['név']

# %% [markdown]
# **Hivatkozás elemre index használatával (nem lehet!)**

# %% [markdown]
# ```python
# barat[0]
# ```

# %% [markdown]
# <sup>Persze ha létrehozunk egy kulcsot egy index értékével akkor lehet, de valójában akkor is a kulccsal hivatkozunk az elemre.</sup>

# %% [markdown]
# **Elemek frissítése, bővítése, törlése (🐟)**

# %%
barat['kor'] = 25

print(barat)

# %%
del(barat['hobby'])

print(barat)

# %% [markdown]
# ## Fontosabb függvények (🐟)

# %% [markdown]
# Néhány a népszerűbb dictionary-ken futtatható függvények közül:
#
# - `len(<dictionary neve>)` → megadja a dictionary-ban található kulcsok számát
#
# - `<dictionary neve>.get(<kulcs>)` → megadja a kulcshoz tartozó értéket, de nem dob hibát ha a kulcs nem található
#
# - `<dictionary neve>.keys()` → visszaadja a dictionary-ben tárolt kulcsokat
#
# - `<dictionary neve>.values()` → visszaadja a dictionary-ben tárolt értékeket
#
# - `<dictionary neve>.items()` → visszaadja a dictionary-ben tárolt kulcs-érték párokat
#
# - `<keresett kulcs> in <dictionary neve>` → megadja, hogy az adott kulcs megtalálható e valahol a dictionary-ben

# %%
len(barat)

# %%
print(barat.get('magasság'))

# %%
barat.keys()

# %%
barat.values()

# %%
barat.items()

# %%
'vicces' in barat

# %% [markdown]
# # További típusok (🐟)

# %% [markdown]
# A listához és dictionary-hez hasonló további adattípus a `tuple` és a `set`, viszont ezeket az alapoknál nem részletezem, csak majd a Python haladóknak kurzus keretein belül.

# %% [markdown]
# ## Tuple

# %% [markdown]
# ### Létrehozás és tulajdonságok

# %% [markdown]
# - Nagyon hasonlít a listához, néhány különbséggel
#
# - Létrehozáskor az elemeket sima zárójelek `()` közé tesszük
#
# - A tuple elemeit nem tudjuk megváltoztatni
#
# ```python
# <tuple neve> = (<első elem>, <második elem>, ..., <utolsó elem>)
# ```

# %%
pelda_tuple = (12, 'alma', 42.42, 'December')

# %% [markdown]
# ```python
# pelda_tuple[0] = 12.03
# ```

# %% [markdown]
# ## Set

# %% [markdown]
# ### Létrehozás és tulajdonságok

# %% [markdown]
# - Nagyon hasonlít a dictionary-hez, néhány különbséggel
#
# - Létrehozáskor az elemeket kapcsos zárójelek `{}` közé tesszük
#
# - A kulcsokhoz nem tartoznak értékek
#
# ```python
# <set neve> = {<első érték>, ..., <utolsó érték>}
# ```

# %%
szamok = {0, 1, 2, 2, 4, 6, 6}

# %%
szamok

# %% [markdown]
# Duplikált elemek eltávolítása listából set-té alakítással (🐟)

# %%
szamok = [0, 1, 2, 2, 4, 6, 6]

szamok = list(set(szamok))
print(szamok)

# %% [markdown]
# <sup>A set-té alakítás megváltoztathatja az elemek sorrendjét nem várt módon!</sup>

# %% [markdown]
# # Feladatok

# %% [markdown]
# A leckéhez tartozó gyakorlati feladatokat [ide kattintva](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/04_Lista_es_dictionary/04_Lista_es_dictionary_gyakorlat.ipynb) éred el.
#
# A feleletválasztós kérdéseket pedig a weboldalamon a találod: <br>
# [Lista és dictionary](https://pythonvilag.hu/pv/python/python_alapjai/04_Lista_es_dictionary/)<br> <br>
#
# Találkozunk a következő leckében!
