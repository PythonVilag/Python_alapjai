# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/04_Lista_tuple_set_es_dictionary/04_Lista_tuple_set_es_dictionary_gyakorlat.ipynb)

# %% [markdown]
# # 1. Feladat

# %% [markdown]
# - Hozz látre egy üres listát
# - Kérj be 3 számot és mentsd el őket a listába
# - Számold ki az elemek összegét, majd add hozzá a listához
# - Írd ki az így kapott új listát sorbarendezve
#
# Példa:
# > Első elem: 4
# > Második elem: 6
# > Hardmadik elem: -1
# > Kiegészített lista sorba rendezve: [-1, 4, 6, 9]

# %% [markdown]
# # 1. Megoldás

# %%
lista = []

elso_elem = int(input('Első elem: '))
lista.append(elso_elem)

masodik_elem = int(input('Második elem: '))
lista.append(masodik_elem)
             
harmadik_elem = int(input('Hardmadik elem: '))
lista.append(harmadik_elem)

lista.append(sum(lista))

print(sorted(lista))
# Out:
# Első elem: 4
# Második elem: 6
# Hardmadik elem: -1
# [-1, 4, 6, 9]
