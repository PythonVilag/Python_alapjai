# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/05_Elagazasok_es_igazsagvizsgalat/05_Elagazasok_es_igazsagvizsgalat_elmelet.ipynb)

# %% [markdown]
# # Elágazás

# %% [markdown]
# - Lehetőséget biztosít, hogy különböző feltételek mellett a programunk máshogyan viselkedjen
#
# - Több feltételt is szabhatunk, illetve azt is megadhatjuk mit csináljon a program ha egyik feltétel sem teljesül

# %% [markdown]
# ## Létrehozás és tulajdonságok

# %% [markdown]
# - 3 kulcsszó áll a rendelkezésünkre elágazások kezelésére: `if`, `elif` és `else`
#
# - Ezek közül az utolsó kettő opcionális
#
# - `if` és `elif` esetén egy feltételnek kell követnie a kulcsszót, amely ha igaz, akkor a feltételhez tartozó kódrészlet kiértékelésre kerül
#
# - A parancssorok végén kettőspont karakter (`:`) található, és a következő sorok bentebb vannak húzva
#
# - A behúzás jelöli, hogy mi az a kódrészlet, ami akkor fut le, ha az előtte lévő feltétel igaz volt
#
# - A parancshoz tartozó alkód a későbbiekben is többször elő fog még jönni
#
# ```python
# if <egyik feltétel>:
#   <csinálj valamit ha <egyik feltétel> logikai értéke igaz>
# elif <másik feltétel>:
#   <csinálj valamit ha <egyik feltétel> hamis és <másik feltétel> igaz>
# ...
# else:
#   <csinálj valamit ha egyik korábbi feltétel sem igaz>
# ```

# %% [markdown]
# <sup>A feltétel után kettőspont van és az adott feltételhez tartozó kód bentebb van húzva!</sup>
#
# <sup>Ez jelenti azt, hogy melyik az a sor, amelyik még az elágazáshoz tartozik és melyik, ami már nem.</sup>

# %%
jo_a_kedvem = True

if jo_a_kedvem:
  print('Ütöm a kezemet :)')
else:
  print('Nem ütöm a kezemet :(')

print('Ez a sor a feltételektől függetlenül lefut.')
# Out:
# Ütöm a kezemet :)
# Ez a sor a feltételektől függetlenül lefut.

# %%
#@title Elágazás futásának szemléltetése { display-mode: "form" }
from IPython.display import IFrame
iframe_url = "https://pythontutor.com/iframe-embed.html#code=jo_a_kedvem%20%3D%20False%0A%0Aif%20jo_a_kedvem%3A%0A%20%20print%28'%C3%9Ct%C3%B6m%20a%20kezemet%20%3A%29'%29%0Aelse%3A%0A%20%20print%28'Nem%20%C3%BCt%C3%B6m%20a%20kezemet%20%3A%28'%29%0A%0Aprint%28'Ez%20a%20sor%20a%20felt%C3%A9telekt%C5%91l%20f%C3%BCggetlen%C3%BCl%20lefut.'%29&codeDivHeight=600&codeDivWidth=800&cumulative=true&curInstr=0&heapPrimitives=nevernest&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false"
IFrame(src=iframe_url, width=1200, height=600)

# %% [markdown]
# `elif`, mint az `else if` összevonva (😊)
# <details>
# <img src="https://github.com/PythonVilag/Python_alapjai/blob/main/05_Elagazasok_es_igazsagvizsgalat/data/elif.jpg?raw=true" alt="drawing"/>
# </details>

# %% [markdown]
# ## Logikai értékek (bool)

# %% [markdown]
# ### Létrehozás

# %%
igaz = True

# %%
hamis = False

# %% [markdown]
# ### Műveletek

# %% [markdown]
# **És**

# %%
igaz and hamis
# Out:
# False

# %% [markdown]
# **Vagy**

# %%
igaz or hamis
# Out:
# True

# %% [markdown]
# **Nem**

# %%
not hamis
# Out:
# True

# %% [markdown]
# <sup>A logikai kapukról és azok kimeneteiről [itt olvashatsz részletesebben](https://hu.wikipedia.org/wiki/Logikai_kapu).</sup>

# %% [markdown]
# # Összehasonlító műveletek

# %% [markdown]
# ## Egyenlő

# %% [markdown]
# Fontos, hogy az egyenlőséget dupla egyenlőségjellel kell vizsgálni. A sima egyenlőség az az értékadás.

# %%
5 == 8
# Out:
# False

# %%
4 == 4
# Out:
# True

# %%
'alma' == 'körte'
# Out:
# False

# %%
'alma' == 'alma'
# Out:
# True

# %% [markdown]
# ## Nem egyenlő

# %%
5 != 8
# Out:
# True

# %%
4 != 4
# Out:
# False

# %%
'alma' != 'körte'
# Out:
# True

# %%
'alma' != 'alma'
# Out:
# False

# %% [markdown]
# ## Kisebb/nagyobb

# %%
5 < 8
# Out:
# True

# %%
5 > 8
# Out:
# False

# %%
4 < 4
# Out:
# False

# %%
'alma' < 'körte'
# Out:
# True

# %%
'alma' < 'k'
# Out:
# True

# %% [markdown]
# <sup>abc sorrendes [ASCII](https://www.ascii-code.com/) összehasonlítás karakterenként</sup>

# %% [markdown]
# ## Kisebb egyenlő/nagyobb egyenlő

# %%
5 <= 8
# Out:
# True

# %%
5 >= 8
# Out:
# False

# %%
4 <= 4
# Out:
# True

# %%
'alma' <= 'alma'
# Out:
# True

# %% [markdown]
# # Típus konverziók

# %% [markdown]
# ## Szám → Logikai érték

# %% [markdown]
# Ha az érték nem 0, akkor Igaz:

# %%
bool(1.2)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %% [markdown]
# ## Szöveg → Logikai érték

# %% [markdown]
# Ha a szöveg nem üres akkor Igaz:

# %%
bool('Nem üres szöveg')
# Out:
# True

# %%
bool(" ")
# Out:
# True

# %%
bool('')
# Out:
# False

# %% [markdown]
# ## Lista/Dictionary → Logikai érték

# %% [markdown]
# Ha a lista vagy dictionary nem üres akkor Igaz:

# %%
bool(['1 elemű lista'])
# Out:
# True

# %%
bool({'elem': 1})
# Out:
# True

# %%
bool([0])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool({})
# Out:
# False

# %% [markdown]
# # Példák

# %% [markdown]
# ## Program futásának megerősítése

# %%
megerosites = input('Szeretnéd, hogy a kód lefusson? (igen/nem): ')

if megerosites == 'igen':
  print('Program fut. Találkozunk 30 perc múlva!')

if megerosites == 'nem':
  print('A kód nem fut le.')

else:
  print('Nem megfelelő bemeneti érték!')
# Out:
# Szeretnéd, hogy a kód lefusson? (igen/nem): igen
# Program fut. Találkozunk 30 perc múlva!
# Nem megfelelő bemeneti érték!

# %% [markdown]
# Fontos, hogy az `else` mindig csak a legutóbbi `if` - `elif` sorozatot veszi figyelembe. Vagyis itt elindult egy "sorozat" az `if megerosites == 'igen'` sorral, majd egyből kezdődött egy újabb az `if megerosites == 'nem'`-el.
#
# Ha az egészet egy sorozatként akarjuk definiálni, akkor a második `if`-et `elif`-re kell cserélnünk.

# %%
megerosites = input('Szeretnéd, hogy a kód lefusson? (igen/nem): ')

if megerosites == 'igen':
  print('Program fut. Találkozunk 30 perc múlva!')
  
elif megerosites == 'nem':
  print('A kód nem fut le.')

else:
  print('Nem megfelelő bemeneti érték!')
# Out:
# Szeretnéd, hogy a kód lefusson? (igen/nem): yes
# Nem megfelelő bemeneti érték!

# %% [markdown]
# ## Szám paritásának vizsgálata

# %%
szam = int(input('Kérlek add meg a vizsgálandó számot: '))

print(f'A szám maradéka 2-vel osztva: {szam % 2}')

if szam % 2 == 0:
  print('A megadott szám páros.')
else:
  print('A megadott szám páratlan.')
# Out:
# Kérlek add meg a vizsgálandó számot: 12
# A szám maradéka 2-vel osztva: 0
# A megadott szám páros.

# %% [markdown]
# ## Teszt érdemjegy kiírása pont alapján

# %% [markdown]
# Az alábbi ponthatárokkal fogunk dolgozni:
#
# 0 - 40: elégtelen
# 41 - 55: elégséges
# 56 - 70: közepes
# 71 - 85: jó
# 86 - 100: jeles

# %%
pontszam = int(input("A teszten megszerzett pontszámod: "))

if pontszam > 85:
  print('Jeles')
elif pontszam > 70:
  print('Jó')
elif pontszam > 55:
  print('Közepes')
elif pontszam > 40:
  print('Elégséges')
else:
  print('Elégtelen')
# Out:
# A teszten megszerzett pontszámod: 1000
# Jeles

# %% [markdown]
# ## Egymásba ágyazott elágazások

# %%
hus = False
zoldseg = False

if hus:
  if zoldseg:
    print('Szereted a húst és a zöldségeket is.')
  else:
    print('Csak a húst szereted, a zölségeket nem.')
else:
  if zoldseg:
    print('Nem szereted a húst, de szereted a zöldségeket.')
  else:
    print('A húst és a zölségeket sem szereted.')
# Out:
# A húst és a zölségeket sem szereted.

# %%
hus = False
zoldseg = False

if hus and zoldseg:
  print('Szereted a húst és a zöldségeket is.')
elif hus and not zoldseg:
  print('Csak a húst szereted, a zölségeket nem.')
elif not hus and zoldseg:
  print('Nem szereted a húst, de szereted a zöldségeket.')
else:
  print('A húst és a zölségeket sem szereted.')
# Out:
# A húst és a zölségeket sem szereted.

# %%
#@title Elágazás futásának szemléltetése { display-mode: "form" }
iframe_url = "https://pythontutor.com/iframe-embed.html#code=hus%20%3D%20True%0Azoldseg%20%3D%20True%0A%0Aif%20hus%20and%20zoldseg%3A%0A%20%20print%28'Szereted%20a%20h%C3%BAst%20%C3%A9s%20a%20z%C3%B6lds%C3%A9geket%20is.'%29%0Aelif%20hus%20and%20not%20zoldseg%3A%0A%20%20print%28'Csak%20a%20h%C3%BAst%20szereted,%20a%20z%C3%B6ls%C3%A9geket%20nem.'%29%0Aelif%20not%20hus%20and%20zoldseg%3A%0A%20%20print%28'Nem%20szereted%20a%20h%C3%BAst,%20de%20szereted%20a%20z%C3%B6lds%C3%A9geket.'%29%0Aelse%3A%0A%20%20print%28'A%20h%C3%BAst%20%C3%A9s%20a%20z%C3%B6ls%C3%A9geket%20sem%20szereted.'%29&codeDivHeight=600&codeDivWidth=800&cumulative=true&curInstr=0&heapPrimitives=nevernest&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false"
IFrame(src=iframe_url, width=1200, height=600)

# %% [markdown]
# # Feladatok

# %% [markdown]
# A leckéhez tartozó gyakorlati feladatokat [ide kattintva](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/05_Elagazasok_es_igazsagvizsgalat/05_Elagazasok_es_igazsagvizsgalat_gyakorlat.ipynb) éred el.
#
# A feleletválasztós kérdéseket pedig a weboldalamon a találod: <br>
# [Elágazások és igazságvizsgálat](https://pythonvilag.hu/pv/python/python_alapjai/05_Elagazasok_es_igazsagvizsgalat/)<br> <br>
#
# Találkozunk a következő leckében!
