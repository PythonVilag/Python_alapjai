# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/01_A_Pyton_programozasi_nyelvrol/01_A_Pyton_programozasi_nyelvrol.ipynb)

# %% [markdown]
# # Általános információk

# %% [markdown]
# ## Futtatás

# %% [markdown]
# * A kód futtatásához kattintsunk a cellába és nyomjuk meg a Shift + Enter billentyű kombinációt.
#
# * A program futásának sorrendjét a cellák futtatási sorrendje határozza meg.
#
# * Egy cellán belül a Python kód fentről lefele soronként értékelődik ki.
#
# * Ha hamarabb hivatkozunk egy elemre, minthogy létrehozzuk azt, hibát kapunk.
#
# * Egy cellát sokszor lefuttathatunk, és cella készíthető gyors "kipróbálások" céljából is.
#
# * Ha a cellának van kimenete az a cella alatt jelenik meg.
#
# * A memóriában elmentett változók törölhetők a futtatókörnyezet újraindításával.

# %%
def print_hi():
  print('Hi!')

# %%
print_hi()
# Out:
# Hi!

# %% [markdown]
# # Segítségkérés

# %% [markdown]
# Mivel a tananyag nem tud az elérhető parancsok minden apró részletére kitérni, így fontos, hogy mi magunk is meg tudjuk keresni bizonyos problémákra a választ.

# %% [markdown]
# ## Internetes

# %% [markdown]
# Google-be írjuk be a problémát angolul, minél kevesebb kulcsszó használatával.
#
# Példa: Hogy tudom vizsgálni, hogy a szövegem egy bizonyos karakter sorozattal kezdődik?
#
# Kulcsszavak:
# - python
# - string
# - starts with
#
# Keresés:
#
# https://letmegooglethat.com/?q=python+string+starts+with
#
#
# Egyik top találat:
#
# https://www.w3schools.com/python/ref_string_startswith.asp

# %%
txt = "Hello, welcome to my world."

x = txt.startswith("Hello")

print(x)
# Out:
# True

# %% [markdown]
# ## Programkódos

# %% [markdown]
# A ```help()``` függvényt meghívva betekintést kapunk a hivatalos dokumentációba.

# %%
help(str)

# %% [markdown]
# Vagy még specifikusabb adatra meghívva a ```help()```-et további információkhoz tudunk jutni

# %%
help(str.startswith)
# Out:
# Help on method_descriptor:
#
# startswith(...)
#     S.startswith(prefix[, start[, end]]) -> bool
#
#     Return True if S starts with the specified prefix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     prefix can also be a tuple of strings to try.
