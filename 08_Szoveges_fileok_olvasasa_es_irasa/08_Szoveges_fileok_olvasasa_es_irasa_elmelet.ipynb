# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/08_Szoveges_fileok_olvasasa_es_irasa/08_Szoveges_fileok_olvasasa_es_irasa_elmelet.ipynb)

# %% [markdown]
# # File kezelés

# %% [markdown]
# Általános lépések:
#
# - File megnyitása, a tartalom eléréséhez
# - File-ból az adatok kiolvasás/file-ba az adatok írása
# - File bezárása, hogy a a többi program is hozzáférjen
#
# Struktúra:
# ```python
# with open('file_neve', 'megnyitas_tipusa') as valtozo_neve:
#   csinalj valamit valtozo_neve-vel
# ```
#
# A `with` parancs automatikusan bezárja a file, és kezeli a futtatás közbeni esetleges hibákat
#
# A megnyitás típusa általában olvasás: 'r' vagy írás 'w'

# %% [markdown]
# # Adatok kiírása

# %%
gyumolcsok = ['alma   ', 'banán     ', 'narancs  ', 'körte', 'dinnye', 'paradicsom']

# %%
with open('sample_data/text.txt', 'w') as f:
  for elem_szam, gyumolcs in enumerate(gyumolcsok):
    f.write(f'{elem_szam + 1}. {gyumolcs}\n')

# %% [markdown]
# # Adatok beolvasása

# %%
ures_lista = []

# %%
with open('sample_data/text.txt', 'r') as f:
  for sor in f:
    sor = sor.strip()
    ertek = int(sor[0])
    ures_lista.append(ertek)

# %%
ures_lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
sum(ures_lista)
# Out:
# 21

# %% [markdown]
# # Extra

# %%
gyumolcs_lista = []
with open('sample_data/text.txt', 'r') as adat:
  for elem_szam, sor in enumerate(adat):
    if elem_szam <= 2:
      gyumolcs = sor.strip().split()
      gyumolcs_lista.append(gyumolcs[-1])

print(gyumolcs_lista)
# Out:
# ['alma', 'banán', 'narancs']

# %% [markdown]
# FizzBuzz

# %%
for szam in range(1, 17):
  if (szam % 3 == 0) and (szam % 5 == 0):
    print('FizzBuzz')
  elif szam % 3 == 0:
    print('Fizz')
  elif szam % 5 == 0:
    print('Buzz')
  else:
    print(szam)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16

# %%
for szam in range(1, 17):
  kimenet = ''
  if szam % 3 == 0:
    kimenet += 'Fizz'
  if szam % 5 == 0:
    kimenet += 'Buzz'

  if len(kimenet) == 0:
    kimenet = szam

  print(kimenet)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
