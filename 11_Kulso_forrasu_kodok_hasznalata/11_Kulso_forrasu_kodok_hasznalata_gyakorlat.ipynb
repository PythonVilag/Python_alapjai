# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/11_Kulso_forrasu_kodok_hasznalata/11_Kulso_forrasu_kodok_hasznalata_gyakorlat.ipynb)

# %% [markdown]
# # 1. Feladat

# %% [markdown]
# - Hívd be a kódodba a random modult
# - Kérj be a felhasználótól egy szót ami "kő", "papír" vagy "olló"
# - Generálj egy véletlenszerű értéket a programon belül
# - Írd ki a gép véletlenszerű választát és hogy ki nyerte meg a kő-papír-ollót
#
# Példa:
# > Kő, papír vagy olló: kő
# > A program ollót generált: nyertél

# %% [markdown]
# # 2. Feladat

# %% [markdown]
# # 3. Feladat

# %% [markdown]
# #  1. Feladat megoldás

# %% [markdown]
# # 2. Feladat megoldás

# %% [markdown]
# # 3. Feladat megoldás
