# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/06_Ciklusok_es_iteracio/06_Ciklusok_es_iteracio_gyakorlat.ipynb)

# %% [markdown]
# # 1. Feladat

# %% [markdown]
# ## Leírás
#
# - Előző FizzBuzz-os feladat továbbfejlesztése
# - Bekérsz egy számot és addig kiírod az összes pozitív egész számot
# - Ha a szám osztható 3-al akkor a szám helyett 'Fizz'
# - Ha a szám osztható 5-el akkor a szám helyett 'Buzz'
# - Ha a szám osztható 3-al és 5-el is, akkor a szám helyett 'FizzBuzz'
#
# Ha készen vagy megnézheted az [alábbi videót](https://www.youtube.com/watch?v=QPZ0pIK_wsc) és ez alapján javíthatod a kódodat

# %% [markdown]
# ## Megoldás

# %% [markdown]
# # 2. Feladat

# %% [markdown]
# ## Leírás
#
# - Kérj be egy egész számot
# - Írd ki az összes osztóját

# %% [markdown]
# ## Megoldás

# %% [markdown]
# # 3. Feladat

# %% [markdown]
# ## Leírás
#
# - Kérj be egy egész számot
# - Vizsgáld meg, hogy a szám prímszám-e
# - Írd ki a konklúziót

# %% [markdown]
# ## Megoldás
