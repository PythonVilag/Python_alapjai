# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/09_Hibakezeles_es_hiba_tipusok/09_Hibakezeles_es_hiba_tipusok_elmelet.ipynb)

# %%
try:
  pass
except:
  pass

# %%
fileok = ['a.txt', 'b.txt', 'c.txt', 'd.txt']
beolvasott = []

# %%
for f in fileok:
  try: 
    fi = open(f, 'r')
    beolvasott.append(fi)
  except FileNotFoundError:
    print('Addot névvel nem található file')
# Out:
# Addot névvel nem található file

# %%
beolvasott
# Out:
# [<_io.TextIOWrapper name='a.txt' mode='r' encoding='UTF-8'>,
#  <_io.TextIOWrapper name='b.txt' mode='r' encoding='UTF-8'>,
#  <_io.TextIOWrapper name='c.txt' mode='r' encoding='UTF-8'>]

# %%
oszto = 1

# %%
try:
  print(42/oszto)
except ZeroDivisionError:
  print('0-val nem illik oszatni')
# Out:
# 42.0

# %%
try:
  print(42/oszto)
except as e:
  print('0-val nem illik oszatni')
