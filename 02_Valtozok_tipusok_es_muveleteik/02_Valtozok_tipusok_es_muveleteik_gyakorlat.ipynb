# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/02_Valtozok_tipusok_es_muveleteik/02_Valtozok_tipusok_es_muveleteik_gyakorlat.ipynb)

# %% [markdown]
# # 1. Feladat

# %% [markdown]
# * Hozz létre egy változót, amiben a mai nap elfogyasztott pizzák számát (nekem 0) tároljuk
# * Figyelj, hogy olyan váltózónévvel mentsd el, ami tükrözi a változó értelmét
# * Növeld meg a változó értékét 1-gyel (nem muszáj ehhez pizzát is enni elég ha elképzeljük)
# * Legyen a változó egy cella visszatérési értéke, hogy lássuk az értékét

# %% [markdown]
# # 2. Feladat

# %% [markdown]
# Találd ki, hogy mi az alábbi változók típusa
#
# ```python
# type("13") = ?
# type(int(13.1)) = ?
# type('14.5') = ?
# type(12) = ?
# type(float(15)) = ?
# type(15.0) = ?
# type(int(float(str(17.4)))) = ?
# type('"14"') = ?
# type(str(12.3)) = ?
# ```

# %% [markdown]
# # 3. Feladat

# %% [markdown]
# Találd ki, hogy mi az alábbi műveletek eredménye:
#
# ```python
# 3 ** 3 = ?
# 13 // 4 = ?
# 16 % 6 = ?
# 'A majomnál ' + str(15) + ' banán van.' * 2 = ?
# 'Ebben a szövegben, van egy vessző.'.find('e') = ?
# len('Hello!') = ?
# True and (not False) = ?
# bool('' or 0.0) = ?
# ```

# %% [markdown]
# # 1. Feladat megoldás

# %%
elfogyasztott_pizza = 0
elfogyasztott_pizza += 1

# %%
elfogyasztott_pizza
# Out:
# 1

# %% [markdown]
# # 2. Feladat megoldás

# %%
type("13")
# Out:
# str

# %%
type(int(13.1))
# Out:
# int

# %%
type('14.5')
# Out:
# str

# %%
type(12)
# Out:
# int

# %%
type(float(15))
# Out:
# float

# %%
type(15.0)
# Out:
# float

# %%
type(int(float(str(17.4))))
# Out:
# int

# %%
type('"14"')
# Out:
# str

# %%
type(str(12.3))
# Out:
# str

# %% [markdown]
# # 3. Feladat megoldás

# %%
3 ** 3
# Out:
# 27

# %%
13 // 4
# Out:
# 3

# %%
16 % 6
# Out:
# 4

# %%
'A majomnál ' + str(15) + ' banán van.'*2
# Out:
# 'A majomnál 15 banán van. banán van.'

# %%
'Ebben a szövegben, van egy vessző.'.find('e')
# Out:
# 3

# %%
len('Hello!')
# Out:
# 6

# %%
True and (not False)
# Out:
# True

# %%
bool('' or 0.0)
# Out:
# False
