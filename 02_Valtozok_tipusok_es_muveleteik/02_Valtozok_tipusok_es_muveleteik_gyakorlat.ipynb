# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/02_Valtozok_tipusok_es_muveleteik/02_Valtozok_tipusok_es_muveleteik_gyakorlat.ipynb)

# %% [markdown]
# # Változók

# %% [markdown]
# Hozz létre egy változót, amiben az elfogyasztott pizzák számát tároljuk.

# %%
elfogyasztott_pizza = 0

# %% [markdown]
# # Típusok

# %% [markdown]
# Találd ki, hogy mi az alábbi változók típusa

# %%
type("13")
# Out:
# str

# %%
type(str(12.3))
# Out:
# str

# %%
type(15.0)
# Out:
# float

# %%
type(int(13))
# Out:
# int

# %%
type('14.5')
# Out:
# str

# %%
type(12)
# Out:
# int

# %%
type(float(15))
# Out:
# float

# %%
type(int(float(str(17.4))))
# Out:
# int

# %%
type('"14"')
# Out:
# str

# %%
# type(int('13.3'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f11333df09b0> in <module>()
# ----> 1 type(int('13.3'))
#
# ValueError: invalid literal for int() with base 10: '13.3'

# %% [markdown]
# # Műveletek

# %% [markdown]
# Találd ki, hogy mi az alábbi műveletek eredménye

# %%
3**3
# Out:
# 27

# %%
13 // 4
# Out:
# 3

# %%
16 % 6
# Out:
# 4

# %%
'A majomnál ' + str(15) + ' banán van.'*2
# Out:
# 'A majomnál 15 banán van. banán van.'

# %%
'Ebben, egy szövegben van egy vessző.'.find(',')
# Out:
# 5

# %%
len('Hello!')
# Out:
# 6

# %%
True and (not False)
# Out:
# True

# %%
bool('' or 0.0)
# Out:
# False
