# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/03_Komment_kiiras_bekeres/03_Komment_kiiras_bekeres_elmelet.ipynb)

# %% [markdown]
# # Komment

# %% [markdown]
# - Segítik a kód megértését
# - Nem zavarja a programot a futásban
# - Lehet egy egész sor, vagy csak a sor végén is
# - Létrehozása:
#   * Kettőskereszt segítségével
#
# ```python
# # <figyelmen kívül hagyott szöveg>
# ```

# %%
# Oldalhossz
a = 10 # [m]

# %%
# Négyzet területe
T = a*a # [m^2]

# %% [markdown]
# # Kiírás

# %% [markdown]
# - Adatok közlése
# - Program működésének ellenőrzése (debuggolás)
# - A függvénynek zárójelek között adjuk meg, mit írjon ki
# - Ha több elemet is ki szeretnénk iratni vesszővel elválasztva tehetjük ezt meg (ezek lehetnek különböző típusúak is)
# - Több elem esetén a print függvény space-el választja el az elemeket (alapértelmezetten)

# %%
print('Hello, világ!')
# Out:
# Hello, világ!

# %%
print('Gyula életkora' + '23' + '!')    # Csak 1 elem, mivel a print csak 1 stringet lát (ami a többinek az összefűzése)
# Out:
# Gyula életkora23!

# %% [markdown]
# <sup>Itt megfigyelhető a space hiánya az életkora szó és a 23 között</sup>

# %%
# Szöveg és szám kiírása
print('Gyula életkora', 23, '!')    # 3 elem, vesszővel elválasztva
# Out:
# Gyula életkora 23 !

# %% [markdown]
# <sup>Itt pedig megfigyelhető az extra space a 23 és a felkiáltójel között</sup>

# %%
print('Gyula életkora ' + str(23) + '!')    # Típus konverzió után már összefűzhetőek a string típusú adatok
# Out:
# Gyula életkora 23!

# %% [markdown]
# Kiírásra a későbbiekben 'formatted string'-eket, úgynevezett f-stringeket fogunk használni. Az f-string olyan szöveg, amely típus konverziók nélkül a szövegbe intergrálva tud kiírni nem szöveg típusú változót, vagy akár műveleti eredményt is.
#
# Használatát a kezdő aposztróf elé tett *f* karakterrel jelöljük, és az integrálandó adatot kapcsos zárójelek *{ }* közé tesszük.

# %%
kor = 46
most = 2022

# %%
f_string = f'Laci idén tölti {kor}. életévét, mert {most - kor}-ben született.'

print(f_string)
# Out:
# Laci idén tölti 46. életévét, mert 1976-ben született.

# %% [markdown]
# f-stringek esetén tört számoknál a kerekítés pontosságát is meg lehet adni.

# %%
szorzat = 13.334*17.951
print(szorzat)
# Out:
# 239.358634

# %%
print(f'Szorzat 3 tizedes pontossággal: {szorzat:.3f}')
# Out:
# Szorzat 3 tizedes pontossággal: 239.359

# %% [markdown]
# # Bekérés

# %% [markdown]
# - A bekért értéket EL KELL MENTENI egy változóba
# - A változó MINDIG STRING típusú, ezért ha más formátumú adatot szeretnénk használni típus konverziót kell alkalmazni:
#
# ```python
# int(input('Bemenet: '))
# ```

# %%
nev = input('Mi a neved? ')
# Out:
# Mi a neved? Laci

# %%
print(f'Szia, {nev}!')
# Out:
# Szia, Laci!

# %%
kor = input('Hány éves vagy? ')
# Out:
# Hány éves vagy? 46

# %%
print('A te korod: ' + kor)
# Out:
# A te korod: 46

# %% [markdown]
# <sup>Ez az összefűzés csak azért működik, mert a 'kor' nevű változó típusa string.</sup>

# %% [markdown]
# Nem működő számösszeadó

# %%
szam_1 = input('Szám 1: ')
szam_2 = input('Szám 2: ')
# Out:
# Szám 1: 11
# Szám 2: 4

# %%
osszeg = szam_1 + szam_2

print(osszeg)
# Out:
# 114

# %% [markdown]
# Numerikussá alakítva a bemenetet

# %%
szam_1 = input('Szám 1: ')
szam_2 = input('Szám 2: ')

# Számok átalakítása numerikus értékké
szam_1 = float(szam_1)
szam_2 = float(szam_2)
# Out:
# Szám 1: 11
# Szám 2: 4

# %%
osszeg = szam_1 + szam_2

print(osszeg)
# Out:
# 15.0

# %% [markdown]
# <sup>A kimenet azért 15.0 és nem 15, mert float típusú számokat adunk össze nem int-eket.</sup>
