# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/03_Komment_kiiras_bekeres/03_Komment_kiiras_bekeres_elmelet.ipynb)

# %% [markdown]
# # Komment

# %% [markdown]
# - Segítik a kód megértését.
#
# - Nem zavarja a programot a futásban.

# %% [markdown]
# ## Létrehozás és tulajdonságok

# %% [markdown]
# - Kettőskereszt használatával
#
# - Több darabot is lehet egy sorba tenni, de ez nem okoz változást
#
# - Lehet egy egész sor, vagy csak a sor végén is
#
# ```python
# # <figyelmen kívül hagyott szöveg>
# ```

# %%
# Oldalhossz
a = 10 # [m]

# %%
# Négyzet területe
T = a * a # [m^2]

# %%
# Eredmény
T

# %% [markdown]
# Kommentek helyett sokszor érdemes a változók elnevezésével utalni a mögöttes tartalomra:
# ```python
# oldalhossz = 10
# negyzet_terulete = oldalhossz * oldalhossz
# negyzet_terulete
# ```

# %% [markdown]
# Kommentek a kódban (😊)
# <details>
# <img src="https://github.com/PythonVilag/Python_alapjai/blob/main/03_Komment_kiiras_bekeres/data/comment.png?raw=true" alt="drawing" width="500"/>
# </details>

# %% [markdown]
# # Kiírás

# %% [markdown]
# - Adatok közlése
#
# - Program működésének ellenőrzése (debuggolás)

# %% [markdown]
# ## Létrehozás és tulajdonságok

# %% [markdown]
# - Kiírni az beépített `print()` függvény segítségével tudunk
#
# - A függvénynek zárójelek között adjuk meg, mit írjon ki
#
# - Ha több elemet is ki szeretnénk iratni vesszővel elválasztva tehetjük ezt meg (ezek lehetnek különböző típusúak is)
#
# ```python
# print(<egyik kiírandó érték>, <másik kiírandó érték>, ...)
# ```

# %% [markdown]
# **Szövek kiírása**

# %%
print('Hello, világ!')

# %%
print('Gyula életkora' + '23' + '!')

# %% [markdown]
# **Szöveg és szám kiírása külön**

# %%
print('Gyula életkora', 23, '!')  # 3 elem, vesszővel elválasztva

# %% [markdown]
# **Szöveg és szám kiírása konverzióval**

# %%
print('Gyula életkora' + str(23) + '!')  # Típus konverzió után már összefűzhetőek a string típusú adatok

# %% [markdown]
# ## Az f-string

# %% [markdown]
# - Kiírásra a későbbiekben 'formatted string'-eket, úgynevezett f-stringeket fogunk használni.
#
# - Az f-string olyan szöveg, amely típus konverziók nélkül a szövegbe integrálva tud kiírni változót, vagy akár műveleti eredményt is.
#
# - Használatát a kezdő aposztróf elé tett `f` karakterrel jelöljük, és az integrálandó adatot kapcsos zárójelek `{ }` közé tesszük.

# %%
kor = 46
most = 2022

# %%
f_string = f'Laci idén tölti {kor}. életévét, mert {most - kor}-ben született.'

print(f_string)

# %% [markdown]
# f-stringek esetén tört számoknál a kerekítés pontosságát is meg lehet adni.

# %%
szorzat = 13.334 * 17.951
print(szorzat)

# %%
print(f'Szorzat 3 tizedes pontossággal: {szorzat:.3f}')

# %% [markdown]
# TODO: decimal érték kiírása: `f"{12:03d}"`
# TODO: space-elés használata: `f"{12:5}"`

# %% [markdown]
# <sup>Vagy használhatjuk a második leckében tanult `round()` függvényt is.</sup>

# %% [markdown]
# ## Print függvény paraméterek (🐟)

# %% [markdown]
# Vizsgáljuk meg a kiírást az alábbi szempontokból:
# - Kiírandó értékek elválasztása
# - Kiírás utána karakter

# %%
print("Jakabnak van", 3, "mogyorója.")
print("Nekem csak", 2, "mogyoróm van.")

# %% [markdown]
# Elválasztó karakter:     space `' '`
# Kiírás utáni karakter:   enter `'\n'`

# %% [markdown]
# Ezeket a paramétereket módosíthatjuk a `sep` és az `end` függvény paraméterek segítségével.

# %%
print("Jakabnak van", 3, "mogyorója.", sep='?', end='\t')
print("Nekem csak", 2, "mogyoróm van.", sep='\n')

# %% [markdown]
# # Bekérés

# %% [markdown]
# - A felhasználó futás közben tud értéket definiálni

# %% [markdown]
# ## Létrehozás és tulajdonságok

# %% [markdown]
# - Értéket bekérni az `input()` függvény segítségével lehet
#
# - A függvénynek zárójelek között adjuk meg, hogy mit írjon ki, mint bekérést segítő utasítás
#
# - A bekért értéket el kell menteni egy változóba, hogy később használni tudjuk
#
# - A bekért érték mindig `str` típusú, ezért ha más formátumú adatot szeretnénk használni típus konverziót kell alkalmazni
#
#
# ```python
# <változó neve> = input(<bekéréshez tartozó utasítás>)
# ```

# %%
nev = input('Mi a neved? ')

# %%
print(f'Szia, ' + nev + ' !')

# %%
kor = input('Hány éves vagy? ')

# %%
print('A te korod: ' + kor)

# %% [markdown]
# <sup>Ez az összefűzés csak azért működik, mert a 'kor' nevű változó típusa string.</sup>

# %% [markdown]
# # Példák

# %% [markdown]
# ## Nem működő szám összeadó

# %%
# Adatok bekérése
szam_1 = input('Szám 1: ')
szam_2 = input('Szám 2: ')

# %%
# Eredmény számítása és kiírása
osszeg = szam_1 + szam_2

print(szam_1 + ' + ' + szam_2 + ' = ' + osszeg)

# %% [markdown]
# ## Működő szám összeadó

# %%
# Adatok bekérése
szam_1 = input('Szám 1: ')
szam_2 = input('Szám 2: ')

# Bekért adatok tört számmá alakítása
szam_1 = float(szam_1)
szam_2 = float(szam_2)

# %%
# Eredmény számítása
osszeg = szam_1 + szam_2

# %% [markdown]
# ```python
# print(szam_1 + ' + ' + szam_2 + ' = ' + osszeg)
# ```

# %%
# Eredmény kiírása
print(f'{szam_1} + {szam_2} = {osszeg}')

# %% [markdown]
# <sup>A kimenet azért 7.0 és nem 7, mert float típusú számokat adunk össze nem int-eket.</sup>

# %% [markdown]
# # Feladatok

# %% [markdown]
# A leckéhez tartozó gyakorlati feladatokat [ide kattintva](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/03_Komment_kiiras_bekeres/03_Komment_kiiras_bekeres_gyakorlat.ipynb) éred el.
#
# A feleletválasztós kérdéseket pedig a weboldalamon a találod: <br>
# [Komment, kiírás és bekérés](https://pythonvilag.hu/pv/python/python_alapjai/03_Komment_kiiras_bekeres/)<br> <br>
#
# Találkozunk a következő leckében!
