# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/12_OPC_Virtualis_kornyezet_alkalmazasa/12_Virtualis_kornyezet_alkalmazasa.ipynb)

# %% [markdown]
# # Feladatok

# %% [markdown]
# A leckéhez tartozó gyakorlati feladatokat [ide kattintva]() éred el.
#
# A feleletválasztós kérdéseket pedig a weboldalamon a találod: <br>
# [Virtuális környezetek alkalmazása]()<br> <br>
#
# Találkozunk a következő leckében!
