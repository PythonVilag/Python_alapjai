# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/10_Osztalyok_es_peldanyaik/10_Osztalyok_es_peldanyaik_gyakorlat.ipynb)

# %% [markdown]
# # 1. Feladat

# %% [markdown]
# # 2. Feladat

# %% [markdown]
# # 3. Feladat

# %% [markdown]
# #  1. Feladat megoldás

# %% [markdown]
# # 2. Feladat megoldás

# %% [markdown]
# # 3. Feladat megoldás
